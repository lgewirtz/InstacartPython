# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import numpy as np 
import os

# %% [markdown]
# ## Import Data

# %%
# setting path to Data Folder

path = r'C:\Documents\Career Foundry\Python\Instacart Basket Analysis\02 Data'

# %%
dfm = pd.read_pickle(os.path.join(path, "Prepped Data", "OLD", "orders_products_mergedOLD2.pkl"))

# %%
dfm.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     0.0         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices    price_range_loc  \
# ...

# %%
dfm.shape
# Out:
# (32403007, 17)

# %%
df = dfm[:1000000]

# %%
df.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     0.0         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices    price_range_loc  \
# ...

# %%
df.shape
# Out:
# (1000000, 17)

# %%
df.groupby('product_name')

# %%
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-6cf574faebea> in <module>
# ----> 1 df.groupby('department_id').agg({'order_number': ['mean']})
#
# NameError: name 'df' is not defined

# %%
dfm.groupby('department_id').agg({'order_number' : ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                15.457838   1  99
# 2                17.277920   1  99
# 3                17.170395   1  99
# 4                17.811403   1  99
# 5                15.215751   1  99
# 6                16.439806   1  99
# 7                17.225802   1  99
# 8                15.340650   1  99
# 9                15.895474   1  99
# 10               20.197148   1  99
# 11               16.170638   1  99
# 12               15.887671   1  99
# 13               16.583536   1  99
# 14               16.773669   1  99
# 15               16.165037   1  99
# 16               17.665606   1  99
# 17               15.694469   1  99
# 18               19.310397   1  99
# 19               17.175919   1  99
# 20               16.473447   1  99
# 21               22.902379   1  99

# %%
department_order_num_mean = dfm.groupby('department_id').agg({'order_number' : ['mean', 'min', 'max']})

# %%
department_order_num_mean.to_clipboard()

# %%
dfm['max_order'] = dfm.groupby(['user_id'])['order_number'].transform(np.max)

# %%
df.head(15)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2398795        1             2                   3                  7
# 2     473747        1             3                   3                 12
# 3    2254736        1             4                   4                  7
# 4     431534        1             5                   4                 15
# 5    3367565        1             6                   2                  7
# 6     550135        1             7                   1                  9
# 7    3108588        1             8                   1                 14
# 8    2295261        1             9                   1                 16
# 9    2550362        1            10                   4                  8
# 10   2968173       15            15                   1                  9
# ...

# %%
df['max_order'].value_counts(dropna = False)
# Out:
# 5     23869
# 4     23730
# 6     23570
# 7     23310
# 8     23027
# 3     22827
# 9     22800
# 99    22457
# 10    21846
# 11    21800
# 12    20760
# 14    20515
# 13    20388
# 15    19604
# 16    18915
# 17    18846
# 19    17838
# 20    17122
# 18    16882
# 21    16525
# 22    16326
# 23    16250
# 24    15411
# 25    15299
# 26    14839
# 27    14090
# 30    13991
# 29    13841
# 28    13295
# 39    12932
# 34    12859
# 31    12733
# 32    12374
# 33    12295
# 36    12239
# 37    11683
# 38    11628
# 42    11594
# 40    11306
# 35    11258
# 41    10759
# 50    10754
# 47    10474
# 43    10350
# 45    10350
# 46    10204
# 2     10126
# 44     9932
# 49     9800
# 48     9705
# 52     9377
# 98     8826
# 51     8703
# 54     8654
# 53     8180
# 55     7929
# 56     7609
# 57     7090
# 61     6621
# 1      5965
# 58     5713
# 59     5588
# 60     5514
# 62     5065
# 65     5044
# 64     5005
# 67     4996
# 97     4935
# 63     4918
# 68     4274
# 70     4179
# ...

# %%
pd.options.display.max_rows = None

# %%
df.head(100)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2398795        1             2                   3                  7
# 2     473747        1             3                   3                 12
# 3    2254736        1             4                   4                  7
# 4     431534        1             5                   4                 15
# 5    3367565        1             6                   2                  7
# 6     550135        1             7                   1                  9
# 7    3108588        1             8                   1                 14
# 8    2295261        1             9                   1                 16
# 9    2550362        1            10                   4                  8
# 10   2968173       15            15                   1                  9
# ...

# %%
df.loc[df['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df.loc[(df['max_order'] <= 40) & (df['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df.loc[df['max_order'] <= 10, 'loyalty_flag'] = 'New customer'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     0.0         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices    price_range_loc  \
# ...

# %%
df['loyalty_flag'].value_counts()
# Out:
# Regular customer    463844
# Loyal customer      335086
# New customer        201070
# Name: loyalty_flag, dtype: int64

# %%
df[['user_id', 'order_number', 'loyalty_flag', 'max_order' ]].head(30)
# Out:
#     user_id  order_number      loyalty_flag  max_order
# 0         1             1      New customer         10
# 1         1             2      New customer         10
# 2         1             3      New customer         10
# 3         1             4      New customer         10
# 4         1             5      New customer         10
# 5         1             6      New customer         10
# 6         1             7      New customer         10
# 7         1             8      New customer         10
# 8         1             9      New customer         10
# 9         1            10      New customer         10
# 10       15            15  Regular customer         22
# 11       15            17  Regular customer         22
# 12       15            18  Regular customer         22
# 13       15            21  Regular customer         22
# 14       15            22  Regular customer         22
# 15       19             2      New customer          7
# ...

# %%
df.to_pickle(os.path.join(path, "Prepped Data", "ords_prods_merged_SUBSET.pkl"))
